# %%
array = ['水','金','地','火','木','土','天','海','冥']

for planet in array:
  print(planet)

length = len(array)

i = 0
while i < length:
  print(array[i])
  i += 1
# Out:
# 9
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
